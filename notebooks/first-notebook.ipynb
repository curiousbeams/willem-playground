# %%
import abtem
import ase

atoms = ase.build.fcc111('Au', size=(3, 2, 12),orthogonal=True,vacuum=0)
potential = abtem.Potential(
    atoms,
    sampling=0.1,
    device='gpu'
).build().compute()
# Out:
# tasks:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
import os
os.environ['PATH']
# Out:
# '/home/wdekleijne/git-repos/willem-playground/.venv/bin:/opt/spack_new/linux-ubuntu24.04-x86_64_v4/gcc-10.5.0/cuda-12.6.2-oayiso7mc4lahr2iqho53ujqqssnluzl/bin:/home/wdekleijne/.vscode-server/cli/servers/Stable-072586267e68ece9a47aa43f8c108e0dcbf44622/server/bin/remote-cli:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/opt/global/bin'
